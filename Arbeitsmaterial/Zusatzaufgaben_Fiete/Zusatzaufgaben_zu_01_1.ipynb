# %% [markdown]
# <!-- Version 1.4, Paul Testa, 04.05.2022 -->
#
# # **Python für Ingenieure**
#
# # Zusatzaufgaben zu 01_1_Variablen.ipynb
#
# Diese Zusatzaufgaben sind grundsätzlich **freiwillig**. <br>
# Sie sollen Ihnen dabei helfen, die praktische Anwendung des vermittelten Stoffs zu üben und zu festigen. <br>
# <br>
# Außerdem wollen wir Sie ermuntern, sich im Forum **Python-Hilfe** über die Kurs-Inhalte auszutauschen, insbesondere auch über Ihre mehr oder weniger erfolgreichen Ansätze zur Lösung dieser Zusatzaufgaben. Die Diskussion über gescheiterte Ansätze ist dabei explizit erwünscht.<br>
# Die Musterlösung zu den Zusatzaufgaben veröffentlichen wir, sobald es einige Lösungsvorschläge in Forum gibt.

# %% [markdown]
# ## 1.1. Einfache Datentypen
#
# **1. <br>
# Worin unterscheiden sich die Variablen `a`, `b` und `c`? <br>
# Schreiben Sie Ihre Antwort als Kommentar in den Code-Block!**

# %%
a = 42
b = 42.0
c = 42 + 0j

# Antwort: a is a int, b is a float and c a complex

# %% [markdown]
# **2. <br>
# Mit welchem Befehl lässt sich der Typ einer Variable bestimmen? <br>
# Bestimmen Sie den Typ von `a`, `b` und `c`!**

# %%
# Antwort: type(a)

type(a)
# Out:
# int

# %% [markdown]
# **3. <br>
# Überlegen Sie <u>zuerst</u> von welchem Typ die Ergebnisse der folgenden Operationen sind und überprüfen Sie anschließend Ihre Antworten!**

# %%
d = a + a # int
e = a + b # float
f = a + c # complex

g = a * b # float
h = a * c # complex

i = a**a # int
k = a**b # float
l = b**a # float

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
print(type(h))
print(type(i))
print(type(k))
print(type(l))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# **4. <br>
# Überlegen Sie <u>zuerst</u> von welchem Typ die Ergebnisse der folgenden Operationen sind und überprüfen Sie anschließend Ihre Antworten!**

# %%
m = a / a
n = a // a
o = a // b

p = a % 5
q = b % 5

# Antwort:

# m hat den Typ float
# n hat den Typ int
# o hat den Typ float
# p hat den Typ int
# q hat den Typ float

print(type(m))
print(type(n))
print(type(o))
print(type(p))
print(type(q))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# <class 'float'>

# %% [markdown]
# **5. <br>
# Überlegen Sie <u>zuerst</u> ob die Booleans `b1` bis `b8` jeweils *True* oder *False* sind und überprüfen Sie anschließend Ihre Antworten! <br> Wie erklären Sie sich das Verhalten, das bei `b3` bis `b8` auftritt?**

# %%
b1 = 42 > 5
b2 = 42.0 > 42
b3 = True > False
b4 = (True + True) > True
b5 = (True * True) > True
b6 = 0.5 > True
b7 = 0.5 > False
b8 = 42 > True

# Antwort:
print(b1)
print(b2)
print(b3)
print(b4)
print(b5)
print(b6)
print(b7)
print(b8)
# Out:
# True
# False
# True
# True
# False
# False
# True
# True

# %% [markdown]
# **6. <br>
# Bestimmen Sie (ohne zu zählen), wieviele der Booleans `b1` bis `b8` *True* sind.**

# %%
# Antwort:
num_of_true = b1 + b2 + b3 + b4 + b5 + b6 + b7 + b8
print(num_of_true)
# Out:
# 5

# %% [markdown]
# **7. <br>
# Warum erzeugt die Ausführung der Anweisung `True/False` eine Fehlermeldung?**

# %%
# Antwort: Divided by 0

# %% [markdown]
# **8. <br>
# Bestimmen Sie mithilfe einer einfachen Operation wieviele Karten übrig bleiben, wenn Sie 32 Karten auf drei Spieler verteilen. <br> Geben Sie das Ergebnis mit `print()` aus.**

# %%
n_Karten = 32
n_Spieler = 3

# Antwort:
amount_of_left_cards = n_Karten%n_Spieler
print(amount_of_left_cards)
# Out:
# 2

# %% [markdown]
# **9. <br>
# Bestimmen Sie mithilfe einer einfachen Operation wieviele vollständige Fußballmanschaften à 11 Spieler sich aus 12.345 Fußballspielern bilden lassen. Wieviele Spieler bleiben traurig zurück? <br>
# Geben Sie die Ergebnisse mit `print()` aus.**

# %%
n_Spieler = 12345
n_Spieler_pro_Mannschaft = 11
n_teams, n_leftover = divmod(n_Spieler,n_Spieler_pro_Mannschaft)
print('there will be', n_teams, 'teams and there will be', n_leftover, 'sad players left over')
# Antwort:
# Out:
# there will be 1122 teams and there will be 3 sad players left over

# %% [markdown]
# **10. <br>
# Berechnen Sie, wie wahrscheinlich es ist, mit einer Münze zehn mal nacheinander *Kopf* zu werfen! <br>
# Berechnen Sie, wie wahrscheinlich es ist mit einem Würfel vier mal hintereinander eine *Sechs* zu würfeln! <br> Welches der beiden Ereignisse ist wahrscheinlicher? <br> Geben Sie die Ergebnisse mit `print()` aus!**

# %%
p_Kopf = 1/2
p_Sechs = 1/6

# Antwort:
coin = (1/2) ** 10
dice = (1/6) ** 4

print(f"Coin (10x heads): {coin:.6f}")
print(f"Dice (4x six):    {dice:.6f}")
print(f"Dice is more likely: {dice > coin}")
# Out:
# Coin (10x heads): 0.000977
# Dice (4x six):    0.000772
# Dice is more likely: False
