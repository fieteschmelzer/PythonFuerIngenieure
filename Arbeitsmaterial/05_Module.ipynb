# %% [markdown]
# # **Python für Ingenieure**
# <!-- Lizensiert unter (CC BY 4.0) Gert Herold, 2022 -->
# # 5. Module
#
# Module sind Dateien, in denen unter anderem Funktionen und Variablen definiert werden, um sie später zur einfachen Verwendung zur Verfügung zu stellen.
# Eine Liste der in der aktuellen Python-Umgebung installierten Module lässt sich abbrufen:

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             _symtable           ftplib              pyparsing
# PIL                 _sysconfig          functools           queue
# __future__          _sysconfigdata__darwin_darwin gc                  quopri
# __hello__           _testbuffer         genericpath         random
# __phello__          _testcapi           getopt              re
# _abc                _testclinic         getpass             readline
# _aix_support        _testclinic_limited gettext             reprlib
# _android_support    _testimportmultiple glob                resource
# _apple_support      _testinternalcapi   graphlib            rlcompleter
# _ast                _testlimitedcapi    grp                 runpy
# _ast_unparse        _testmultiphase     gzip                sched
# _asyncio            _testsinglephase    hashlib             secrets
# _bisect             _thread             heapq               select
# _blake2             _threading_local    hmac                selectors
# _bz2                _tokenize           html                shelve
# _codecs             _tracemalloc        http                shlex
# _codecs_cn          _types              idlelib             shutil
# _codecs_hk          _typing             imaplib             signal
# _codecs_iso2022     _uuid               importlib           site
# _codecs_jp          _warnings           inspect             sitecustomize
# _codecs_kr          _weakref            io                  six
# _codecs_tw          _weakrefset         ipaddress           smtplib
# _collections        _xxtestfuzz         ipykernel           socket
# _collections_abc    _zoneinfo           ipykernel_launcher  socketserver
# _colorize           _zstd               ipython_pygments_lexers sqlite3
# _compat_pickle      abc                 itertools           sre_compile
# _contextvars        annotationlib       jedi                sre_constants
# _csv                antigravity         json                sre_parse
# _ctypes             appnope             jupyter             ssl
# _ctypes_test        argparse            jupyter_client      stack_data
# _curses             array               jupyter_core        stat
# _curses_panel       ast                 keyword             statistics
# _datetime           asttokens           kiwisolver          string
# _dbm                asyncio             linecache           stringprep
# _decimal            atexit              locale              struct
# _elementtree        base64              logging             subprocess
# _functools          bdb                 lzma                symtable
# _hashlib            binascii            mailbox             sys
# _heapq              bisect              marshal             sysconfig
# _hmac               builtins            math                syslog
# _imp                bz2                 matplotlib          tabnanny
# _interpchannels     cProfile            matplotlib_inline   tarfile
# _interpqueues       calendar            mimetypes           tempfile
# _interpreters       cmath               mmap                termios
# _io                 cmd                 modulefinder        test
# _ios_support        code                multiprocessing     textwrap
# _json               codecs              nest_asyncio        this
# _locale             codeop              netrc               threading
# _lsprof             collections         ntpath              time
# _lzma               colorsys            nturl2path          timeit
# _markupbase         comm                numbers             tkinter
# _md5                compileall          numpy               token
# _multibytecodec     compression         opcode              tokenize
# _multiprocessing    concurrent          operator            tomllib
# _opcode             configparser        optparse            tornado
# _opcode_metadata    contextlib          os                  trace
# _operator           contextvars         packaging           traceback
# _osx_support        contourpy           parso               tracemalloc
# _pickle             copy                pathlib             traitlets
# _posixshmem         copyreg             pdb                 tty
# _posixsubprocess    csv                 pexpect             turtle
# _py_abc             ctypes              pickle              turtledemo
# _py_warnings        curses              pickletools         types
# _pydatetime         cycler              pip                 typing
# _pydecimal          dataclasses         pkgutil             unicodedata
# _pyio               datetime            platform            unittest
# _pylong             dateutil            platformdirs        urllib
# _pyrepl             dbm                 plistlib            uuid
# _queue              debugpy             poplib              venv
# _random             decimal             posix               warnings
# _remote_debugging   decorator           posixpath           wave
# _scproxy            difflib             pprint              wcwidth
# _sha1               dis                 profile             weakref
# _sha2               doctest             prompt_toolkit      webbrowser
# _sha3               email               pstats              wsgiref
# _signal             encodings           psutil              xml
# _sitebuiltins       ensurepip           pty                 xmlrpc
# _socket             enum                ptyprocess          xxlimited
# _sqlite3            errno               pure_eval           xxlimited_35
# _sre                executing           pwd                 xxsubtype
# _ssl                faulthandler        py_compile          zipapp
# _stat               fcntl               pyclbr              zipfile
# _statistics         filecmp             pydoc               zipimport
# _string             fileinput           pydoc_data          zlib
# _strptime           fnmatch             pyexpat             zmq
# _struct             fontTools           pygments            zoneinfo
# _suggestions        fractions           pylab
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %% [markdown]
# ## 5.1. Import von Modulen
#
# Um die Funktionalitäten eines Moduls zu verwenden, muss dieses importiert werden:

# %%
import wort
wort.hallo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import wort
#       2 wort.hallo
#
# ModuleNotFoundError: No module named 'wort'

# %%
import wort as wt
wt.hallo

# %%
from wort import hallo
hallo

# %%
from wort import hallo as moin
moin

# %%
from wort import *
lorem

# %%
anzahl_vokale(lorem)

# %% [markdown]
# ## 5.2. Standardmodule
#
# Bei jeder Python-Installation werden einige Module standardmäßig mitgeliefert.
# Eine ausführliche Beschreibung der Module und ihrer Funktionalitäten findet sich unter https://docs.python.org/3/library/.
# Einige Beispiele im Folgenden:

# %% [markdown]
# ### 5.2.1 [`os`](https://docs.python.org/3/library/os.html)
# Arbeiten im Dateisystem

# %%
import os

# %%
os.getcwd()

# %%
os.listdir()

# %% [markdown]
# Verzeichnisse erstellen, umbennen und entfernen:

# %%
os.mkdir('Ein_neuer_Ordner')

# %%
os.rename('Ein_neuer_Ordner', 'ABCDEFG')

# %%
os.rmdir('ABCDEFG')

# %% [markdown]
# Datei erstellen und entfernen (für das Erstellen/Überschreiben von Dateien ist kein Modulimport notwendig);

# %%
datei = open('12345.abc', 'w')
datei.write('Ein bisschen Text.\n')
datei.write(os.listdir()[0])
datei.close()

# %%
os.remove('12345.abc')

# %% [markdown]
# ### 5.2.2 [`glob`](https://docs.python.org/3/library/glob.html)
#
# Dateilisten filtern.

# %%
import glob
glob.glob("*.py")

# %% [markdown]
# ### 5.2.3 [`math`](https://docs.python.org/3/library/math.html)
#
# Mathematische Funktionen und Konstanten

# %%
from math import pi,sin,sqrt

sin(pi/4), sqrt(9)

# %% [markdown]
# ### 5.2.4 [`random`](https://docs.python.org/3/library/random.html)
#
# Zufallszahlen und mehr.

# %%
import random

# %% [markdown]
# Gleichverteilte Zufallszahl zwischen 0 und 1:

# %%
#random.seed(1)
random.random()

# %% [markdown]
# Liste zufällig umsortieren:

# %%
a = [1,2,3,4,5,6,7,8]
random.shuffle(a)
a

# %% [markdown]
# Zufällige Ganzzahl zwischen 5 und (inkl.) 20:

# %%
random.randint(5,20)

# %% [markdown]
# ## Übung
#
# **1) In beiden Modulen (wort, math) wird eine Variable `pi` definiert. Beide sollen im Programm verwendet werden. Testen Sie, welche Auswirkungen ein Austausch der ersten beiden Zeilen für die Ausgabe hat. Wie kann das Programm für eine sinnvolle Ausgabe abgeändert werden?**

# %%
from math import *
from wort import *

print("Der 16. Buchstabe des griechischen Alphabets:", pi)

durchmesser = 3
umfang = pi*durchmesser
print("Der Umfang eines Kreises mit einem Durchmesser von %d:" % durchmesser, umfang)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from math import *
# ----> 2 from wort import *
#       3
#       4 print("Der 16. Buchstabe des griechischen Alphabets:", pi)
#       5
#
# ModuleNotFoundError: No module named 'wort'

# %% [markdown]
# **2) Schreiben Sie eine Funktion, die eine Liste mit *n* gleichverteilten Zufallszahlen zurückgibt. Der Parameter *n* soll der Funktion übergeben werden.**

# %% [markdown]
# **3) Schreiben Sie einen Programmabschnitt, der ...**
#   * ... die Datei oder das Verzeichnis mit dem längsten Namen im aktuellen Verzeichnis findet und diesen ausgibt.
#   * ... den Namen mit der höchsten Anzahl an Konsonanten ausgibt.
